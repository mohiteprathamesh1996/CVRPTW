# %% [markdown]
# ### Importing Packages

# %%
import os
import requests
import numpy as np
import pandas as pd
from download_and_extract_data import *

# %%
ZENODO_RECORD_ID = "15672291"
ZENODO_API_URL = f"https://zenodo.org/api/records/{ZENODO_RECORD_ID}"
EXTRACTED_DIR = os.path.join(os.getcwd(), "extracted_data")

# %%
file_name, file_url = get_zip_file_url()

# %%
download_zip(file_name=file_name, file_url=file_url)
# Out:
# ...
# Download complete: /Users/prathameshmohite/Desktop/Data Challenges & Projects/CVRPTW/data.zip
# '/Users/prathameshmohite/Desktop/Data Challenges & Projects/CVRPTW/data.zip'

# %%
extract_zip(zip_path="data.zip")
# Out:
# Extracting data.zip to /Users/prathameshmohite/Desktop/Data Challenges & Projects/CVRPTW/extracted_data...
# Extraction complete: /Users/prathameshmohite/Desktop/Data Challenges & Projects/CVRPTW/extracted_data
